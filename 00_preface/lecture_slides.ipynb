# %% [markdown]
# # Lecture slides
#
# Here are links to the lecture slides
#
# - [Lecture 1](https://nilsjakob.github.io/AC_Power_System_Basics_2026/Lecture1.slides.html#/)
# - [Lecture 2](https://nilsjakob.github.io/AC_Power_System_Basics_2026/Lecture2.slides.html#)
